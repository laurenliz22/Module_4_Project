# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mod-4-Project---Starter-Notebook" data-toc-modified-id="Mod-4-Project---Starter-Notebook-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Mod 4 Project - Starter Notebook</a></span></li><li><span><a href="#Some-Notes-Before-Starting" data-toc-modified-id="Some-Notes-Before-Starting-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Some Notes Before Starting</a></span><ul class="toc-item"><li><span><a href="#Wide-Format-vs-Long-Format" data-toc-modified-id="Wide-Format-vs-Long-Format-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Wide Format vs Long Format</a></span></li></ul></li><li><span><a href="#Helper-Functions-Provided" data-toc-modified-id="Helper-Functions-Provided-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Helper Functions Provided</a></span></li><li><span><a href="#Business-Case" data-toc-modified-id="Business-Case-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Business Case</a></span></li><li><span><a href="#Load-the-Data-and-Change-to-Long-Format" data-toc-modified-id="Load-the-Data-and-Change-to-Long-Format-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Load the Data and Change to Long Format</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Filter-through-New-Orleans-Metropolitan-Area-Counties-and-Zip-Codes" data-toc-modified-id="Filter-through-New-Orleans-Metropolitan-Area-Counties-and-Zip-Codes-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Filter through New Orleans Metropolitan Area Counties and Zip Codes</a></span></li><li><span><a href="#Determine-'Best'-5-Zip-Codes" data-toc-modified-id="Determine-'Best'-5-Zip-Codes-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Determine 'Best' 5 Zip Codes</a></span><ul class="toc-item"><li><span><a href="#Orleans-County" data-toc-modified-id="Orleans-County-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Orleans County</a></span></li><li><span><a href="#Jefferson-County" data-toc-modified-id="Jefferson-County-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Jefferson County</a></span></li><li><span><a href="#Saint-Tammany-County" data-toc-modified-id="Saint-Tammany-County-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Saint Tammany County</a></span></li><li><span><a href="#Saint-John-the-Baptist-County" data-toc-modified-id="Saint-John-the-Baptist-County-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Saint John the Baptist County</a></span></li><li><span><a href="#Plaquemines-County" data-toc-modified-id="Plaquemines-County-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Plaquemines County</a></span></li><li><span><a href="#Saint-Charles-County" data-toc-modified-id="Saint-Charles-County-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>Saint Charles County</a></span></li><li><span><a href="#Saint-Bernard-County" data-toc-modified-id="Saint-Bernard-County-6.2.7"><span class="toc-item-num">6.2.7&nbsp;&nbsp;</span>Saint Bernard County</a></span></li><li><span><a href="#Saint-James-County" data-toc-modified-id="Saint-James-County-6.2.8"><span class="toc-item-num">6.2.8&nbsp;&nbsp;</span>Saint James County</a></span></li></ul></li><li><span><a href="#Five-Zip-Codes:-Set-Up-CSV-Files" data-toc-modified-id="Five-Zip-Codes:-Set-Up-CSV-Files-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Five Zip Codes: Set Up CSV Files</a></span></li></ul></li><li><span><a href="#Step-3:-EDA-and-Visualization" data-toc-modified-id="Step-3:-EDA-and-Visualization-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 3: EDA and Visualization</a></span></li><li><span><a href="#Step-5:-ARIMA-Modeling" data-toc-modified-id="Step-5:-ARIMA-Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Step 5: ARIMA Modeling</a></span></li><li><span><a href="#Step-6:-Interpreting-Results" data-toc-modified-id="Step-6:-Interpreting-Results-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Step 6: Interpreting Results</a></span></li></ul></div>

# %% [markdown]
# # Mod 4 Project - Starter Notebook
#
# This notebook has been provided to you so that you can make use of the following starter code to help with the trickier parts of preprocessing the Zillow dataset.
#
# The notebook contains a rough outline the general order you'll likely want to take in this project. You'll notice that most of the areas are left blank. This is so that it's more obvious exactly when you should make use of the starter code provided for preprocessing.
#
# **_NOTE:_** The number of empty cells are not meant to infer how much or how little code should be involved in any given step--we've just provided a few for your convenience. Add, delete, and change things around in this notebook as needed!
#
# # Some Notes Before Starting
#
# This project will be one of the more challenging projects you complete in this program. This is because working with Time Series data is a bit different than working with regular datasets. In order to make this a bit less frustrating and help you understand what you need to do (and when you need to do it), we'll quickly review the dataset formats that you'll encounter in this project.
#
# ## Wide Format vs Long Format
#
# If you take a look at the format of the data in `zillow_data.csv`, you'll notice that the actual Time Series values are stored as separate columns. Here's a sample:
#
# <img src='~/../images/df_head.png'>
#
# You'll notice that the first seven columns look like any other dataset you're used to working with. However, column 8 refers to the median housing sales values for April 1996, column 9 for May 1996, and so on. This This is called **_Wide Format_**, and it makes the dataframe intuitive and easy to read. However, there are problems with this format when it comes to actually learning from the data, because the data only makes sense if you know the name of the column that the data can be found it. Since column names are metadata, our algorithms will miss out on what dates each value is for. This means that before we pass this data to our ARIMA model, we'll need to reshape our dataset to **_Long Format_**. Reshaped into long format, the dataframe above would now look like:
#
# <img src='~/../images/melted1.png'>
#
# There are now many more rows in this dataset--one for each unique time and zipcode combination in the data! Once our dataset is in this format, we'll be able to train an ARIMA model on it. The method used to convert from Wide to Long is `pd.melt()`, and it is common to refer to our dataset as 'melted' after the transition to denote that it is in long format.
#
# # Helper Functions Provided
#
# Melting a dataset can be tricky if you've never done it before, so you'll see that we have provided a sample function, `melt_data()`, to help you with this step below. Also provided is:
#
# * `get_datetimes()`, a function to deal with converting the column values for datetimes as a pandas series of datetime objects
# * Some good parameters for matplotlib to help make your visualizations more readable.
#
# Good luck!

# %% [markdown]
# # Business Case

# %% [markdown]
# # Load the Data and Change to Long Format

# %%
#import data
import pandas as pd
df = pd.read_csv('zillow_data.csv')
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   ...     2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0   ...     1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0   ...      308000   310000   312500
# 2         3  210400.0  212200.0  212200.0   ...      321000   320600   320200
# 3         4  498100.0  500900.0  503100.0   ...     1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0   ...      119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
#function to rearrange dataframe to have time as a column with value next to it
def melt_data(df):
    melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted

# %%
#run melt function to produce updated dataframe
df = melt_data(df)
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank       time     value
# 0         1 1996-04-01  334200.0
# 1         2 1996-04-01  235700.0
# 2         3 1996-04-01  210400.0
# 3         4 1996-04-01  498100.0
# 4         5 1996-04-01   77300.0

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Filter through New Orleans Metropolitan Area Counties and Zip Codes

# %%
#narrow down dataframe to include only New Orleans zip codes
df_LA = df.loc[df.State =='LA']
print(len(df_LA))
df_LA.head()
# Out:
# 43523
#      RegionID  RegionName            City State        Metro  \
# 386     88757       70726  Denham Springs    LA  Baton Rouge
# 476     88457       70072         Marrero    LA  New Orleans
# 592     88451       70065          Kenner    LA  New Orleans
# 782     88825       70816     Baton Rouge    LA  Baton Rouge
# 787     88414       70001        Metairie    LA  New Orleans
#
#            CountyName  SizeRank       time    value
# 386        Livingston       387 1996-04-01  76000.0
# 476         Jefferson       477 1996-04-01  64200.0
# 592         Jefferson       593 1996-04-01  92600.0
# 782  East Baton Rouge       783 1996-04-01  72200.0
# 787         Jefferson       788 1996-04-01  86400.0

# %%
#look at county names
df_LA.CountyName.unique()
# Out:
# array(['Livingston', 'Jefferson', 'East Baton Rouge', 'Lafayette',
#        'Orleans', 'Ascension', 'Saint Tammany', 'Calcasieu', 'Ouachita',
#        'Rapides', 'Lincoln', 'Tangipahoa', 'Saint John the Baptist',
#        'Terrebonne', 'Natchitoches', 'Vernon', 'Vermilion', 'Morehouse',
#        'Washington', 'Webster', 'Saint Landry', 'Acadia', 'Iberville',
#        'Jefferson Davis', 'West Baton Rouge', 'Plaquemines', 'Franklin',
#        'Avoyelles', 'Saint Charles', 'Union', 'Madison', 'West Feliciana',
#        'Jackson', 'Lafourche', 'Claiborne', 'Concordia', 'Allen',
#        'East Feliciana', 'Bienville', 'Grant', 'Saint Bernard',
#        'Assumption', 'Bossier', 'Caddo', 'De Soto', 'Beauregard',
#        'Pointe Coupee', 'Saint Mary', 'Catahoula', 'West Carroll',
#        'Saint James', 'Richland', 'Caldwell', 'La Salle', 'Evangeline'],
#       dtype=object)

# %%
#Narrow down counties by those in the New Orleans Metropolitan area 
counties = ['Orleans','Jefferson','Saint Bernard','Plaquemines',
            'Saint Tammany','Saint John the Baptist','Saint James','Saint Charles']
df_NO = df_LA.loc[df_LA['CountyName'].isin(counties)]
df_NO.CountyName.unique()
# Out:
# array(['Jefferson', 'Orleans', 'Saint Tammany', 'Saint John the Baptist',
#        'Plaquemines', 'Saint Charles', 'Saint Bernard', 'Saint James'],
#       dtype=object)

# %%
#review how many zip codes exist
len(df_NO.RegionName.unique())
# Out:
# 44

# %% [markdown]
# There are 44 zip codes in the New Orleans Metropolitan Area

# %%
#look at updated dataframe
df_NO.head()
# Out:
#       RegionID  RegionName         City State        Metro CountyName  \
# 476      88457       70072      Marrero    LA  New Orleans  Jefferson
# 592      88451       70065       Kenner    LA  New Orleans  Jefferson
# 787      88414       70001     Metairie    LA  New Orleans  Jefferson
# 1038     88479       70115  New Orleans    LA  New Orleans    Orleans
# 1394     88416       70003     Metairie    LA  New Orleans  Jefferson
#
#       SizeRank       time     value
# 476        477 1996-04-01   64200.0
# 592        593 1996-04-01   92600.0
# 787        788 1996-04-01   86400.0
# 1038      1039 1996-04-01  131700.0
# 1394      1395 1996-04-01   81700.0

# %%
df_NO.drop(columns=['RegionID', 'City', 'State', 'Metro', 'SizeRank'], 
           axis=1, inplace=True)
df_NO.head()
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#       RegionName CountyName       time     value
# 476        70072  Jefferson 1996-04-01   64200.0
# 592        70065  Jefferson 1996-04-01   92600.0
# 787        70001  Jefferson 1996-04-01   86400.0
# 1038       70115    Orleans 1996-04-01  131700.0
# 1394       70003  Jefferson 1996-04-01   81700.0

# %% [markdown]
# ## Determine 'Best' 5 Zip Codes

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def graph(county):
    df_county = df_NO.loc[df_NO.CountyName == county]
    for code in list(df_county.RegionName.unique()):
        df_county_code=df_county.loc[df_county.RegionName == code]
        plt.figure(figsize=(3,3))
        plt.plot(df_county_code.time, df_county_code.value, label=code)
        plt.legend()
        plt.title(county)
        plt.ylabel('price')
        plt.xlabel('year')

# %% [markdown]
# ### Orleans County

# %%
graph('Orleans')

# %% [markdown]
# Orleans county had a bit of a dip during the 2008 crash, but has been increasing since.  We will consider all zip codes, except for zip code = 70131 which is very volatile and zip code = 70122 since we only have data starting in 2014
#
# Zip codes to include: 70115, 70118, 70130

# %% [markdown]
# ### Jefferson County

# %%
graph('Jefferson')

# %% [markdown]
# Jefferson county had larger impacted results due to Hurricane Katrina and the economic crash.  With this volatility we won't consider zip codes in Jefferson county

# %% [markdown]
# ### Saint Tammany County

# %%
graph('Saint Tammany')

# %% [markdown]
# Saint Tammany county had larger impacted results due to the economic crash.  With this volatility we won't consider zip codes in saint tammany county

# %% [markdown]
# ### Saint John the Baptist County

# %%
graph('Saint John the Baptist')

# %% [markdown]
# Saint John the Baptist did not have much volatility based on the economic crash or Hurricane Katrina and will be included = 70068

# %% [markdown]
# ### Plaquemines County

# %%
graph('Plaquemines')

# %% [markdown]
# Plaquemines also did not have much volatility based on the economic crash or natural disasters and will be included  70037

# %% [markdown]
# ### Saint Charles County

# %%
graph('Saint Charles')

# %% [markdown]
# Houses in Saint Charles will not be included because there has not been much increase with the uptake in the market in recent years, therefore this doesn't seem like a solid investment

# %% [markdown]
# ### Saint Bernard County

# %%
graph('Saint Bernard')

# %% [markdown]
# Saint Bernard County is too volatile and won't be included

# %% [markdown]
# ### Saint James County

# %%
graph('Saint James')

# %% [markdown]
# Saint James county has shown intense decline in the last few years and won't be included

# %% [markdown]
# ## Five Zip Codes: Set Up CSV Files

# %% [markdown]
# Therefore to summarize we'll consider the following 5 zip codes:
# - 70115
# - 70118
# - 70130
# - 70068
# - 70037

# %%
#Define separate databases for each zip code
df_70115 = df_NO.loc[df_NO.RegionName == 70115]
df_70118 = df_NO.loc[df_NO.RegionName == 70118]
df_70130 = df_NO.loc[df_NO.RegionName == 70130]
df_70068 = df_NO.loc[df_NO.RegionName == 70068]
df_70037 = df_NO.loc[df_NO.RegionName == 70037]

# %%
#Create csv file for each zip code
df_70115.drop(columns=['RegionName', 'CountyName'], axis=1, inplace=True)
df_70115.set_index('time', inplace=True)
df_70115.to_csv('df_70115')
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Create csv file for each zip code
df_70118.drop(columns=['RegionName', 'CountyName'], axis=1, inplace=True)
df_70118.set_index('time', inplace=True)
df_70118.to_csv('df_70118')
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Create csv file for each zip code
df_70130.drop(columns=['RegionName', 'CountyName'], axis=1, inplace=True)
df_70130.set_index('time', inplace=True)
df_70130.to_csv('df_70130')
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Create csv file for each zip code
df_70068.drop(columns=['RegionName', 'CountyName'], axis=1, inplace=True)
df_70068.set_index('time', inplace=True)
df_70068.to_csv('df_70068')
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Create csv file for each zip code
df_70037.drop(columns=['RegionName', 'CountyName'], axis=1, inplace=True)
df_70037.set_index('time', inplace=True)
df_70037.to_csv('df_70037')
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# # Step 3: EDA and Visualization

# %%
zipcodes = [70115, 70118, 70130, 70068, 70037]
df_zipcodes = df_NO.loc[df_NO.RegionName.isin(zipcodes)]
df_zipcodes.drop('CountyName', axis=1, inplace=True)
df_zipcodes.head()
# Out:
# /Users/lauren/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#       RegionName       time     value
# 1038       70115 1996-04-01  131700.0
# 1723       70118 1996-04-01   87900.0
# 2860       70068 1996-04-01   35800.0
# 4000       70130 1996-04-01  111600.0
# 6635       70037 1996-04-01  104300.0

# %%
df_zipcodes2 = df_zipcodes.groupby('RegionName').aggregate({'value':'median'})
df_zipcodes2.plot(kind='bar')

# %% [markdown]
# # Step 5: ARIMA Modeling

# %% [markdown]
# # Step 6: Interpreting Results
